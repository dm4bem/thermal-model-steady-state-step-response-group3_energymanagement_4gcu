# %% [markdown]
# # Second modification of the thermal model

# %% [markdown]
# For this second modification, we decided to increase the time step in order to prove the importance of the stability of the explicit solution. Although the implicit solution remains stable and identical to the previous solution with an adapted time step, the explicit solution turns instable even though the time step was increased by just one second.

# %%
imposed_time_step = True
Δt = 500    # s, imposed time step

print('Matrices and vectors for thermal circuit from Figure 1') 
df = pd.read_csv('TC.csv')
df.style.apply(lambda x: ['background-color: yellow'
                          if x.name in df.index[-3:] or c in df.columns[-2:]
                          else '' for c in df.columns], axis=1)

# %% [markdown]
# ![418294072_305974459157118_3116304894323973681_n.png](attachment:418294072_305974459157118_3116304894323973681_n.png)
